# %%
with open("/Users/cheapanharith/AI/standform-LLMSCRATCH/idontwanttobehomelesstoo/data", "r")  as file  : 
    data = file.read()
    string = data.encode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 with open("/Users/cheapanharith/AI/standform-LLMSCRATCH/idontwanttobehomelesstoo/data", "r")  as file  :
#       2     data = file.read()
#       3     string = data.encode("utf-8")
#       4
#
# IsADirectoryError: [Errno 21] Is a directory: '/Users/cheapanharith/AI/standform-LLMSCRATCH/idontwanttobehomelesstoo/data'

# %%
ord(" ")
len(" ")
# Out:
# 1

# %%
chr(0)
# Out:
# '\x00'

# %%
print()

# %%
print('\x41')
# Out:
# A

# %%
"this is a test" + chr(0) + "string"
len("this is a test" + chr(0) + "string")
# Out:
# 21

# %%
(print("this is a test" + chr(0) + "string"))
len("this is a teststring")
# Out:
# this is a teststring
# 20

# %%
print("a" + chr(10) + "b")
# Out:
# a
# b

# %%
print("a" + chr(0) + "b")
# Out:
# ab

# %%
c = "ក"
utf8 = c.encode("utf8")
utf16 = c.encode("utf16")
utf32 = c.encode("utf32")

# %%
print(utf8)
print(utf16)
print(utf32)
# Out:
# b'\xe1\x9e\x80'
# b'\xff\xfe\x80\x17'
# b'\xff\xfe\x00\x00\x80\x17\x00\x00'
